# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("pp2.csv")

# %%
data
# Out:
#        표측1   2019      2019.1        2019.2       2019.3         2019.4  \
# 0      표측1  1.사례수  10.유흥/놀이시설  11.경제적인 여행비용  12.잘갖춰진휴양시설  13.기후/뚜렷한 사계절
# 1     1.전체    NaN         6.3           6.2          NaN            NaN
# 2    10.9월    NaN         4.6           5.5          NaN            NaN
# 3   11.10월    NaN         4.9           6.1          NaN            NaN
# 4   12.11월    NaN         3.9           5.6          NaN            NaN
# 5   13.12월    NaN         5.8             4          NaN            NaN
# 6     2.1월    NaN         5.2           6.8          NaN            NaN
# 7     3.2월    NaN         4.7           6.4          NaN            NaN
# 8     4.3월    NaN         6.2           6.7          NaN            NaN
# 9     5.4월    NaN         8.3           6.5          NaN            NaN
# 10    6.5월    NaN         6.7           6.2          NaN            NaN
# 11    7.6월    NaN         9.8           6.6          NaN            NaN
# ...

# %%
data.iloc[:,:96]
# Out:
#        표측1   2019      2019.1        2019.2       2019.3         2019.4  \
# 0      표측1  1.사례수  10.유흥/놀이시설  11.경제적인 여행비용  12.잘갖춰진휴양시설  13.기후/뚜렷한 사계절
# 1     1.전체    NaN         6.3           6.2          NaN            NaN
# 2    10.9월    NaN         4.6           5.5          NaN            NaN
# 3   11.10월    NaN         4.9           6.1          NaN            NaN
# 4   12.11월    NaN         3.9           5.6          NaN            NaN
# 5   13.12월    NaN         5.8             4          NaN            NaN
# 6     2.1월    NaN         5.2           6.8          NaN            NaN
# 7     3.2월    NaN         4.7           6.4          NaN            NaN
# 8     4.3월    NaN         6.2           6.7          NaN            NaN
# 9     5.4월    NaN         8.3           6.5          NaN            NaN
# 10    6.5월    NaN         6.7           6.2          NaN            NaN
# 11    7.6월    NaN         9.8           6.6          NaN            NaN
# ...

# %%
data2 = data.iloc[:,:96].dropna(axis=1)
data2
# Out:
#        표측1      2019.1        2019.2 2019.11    2019.12   2019.13    2019.14  \
# 0      표측1  10.유흥/놀이시설  11.경제적인 여행비용    2.쇼핑  3.음식/미식탐방  4.자연풍경감상  5.역사/문화유적
# 1     1.전체         6.3           6.2    66.2       61.3      36.3       23.6
# 2    10.9월         4.6           5.5    65.1       59.9      36.2       24.9
# 3   11.10월         4.9           6.1    60.6       57.7      42.1       25.3
# 4   12.11월         3.9           5.6    70.4       57.4        37       23.6
# 5   13.12월         5.8             4    68.4         62      38.4         22
# 6     2.1월         5.2           6.8    66.5       64.9      33.9       20.6
# 7     3.2월         4.7           6.4    69.9       65.9      35.9       22.5
# 8     4.3월         6.2           6.7      72       62.8      34.5         20
# 9     5.4월         8.3           6.5    63.8       61.8      39.9         27
# 10    6.5월         6.7           6.2      66       60.8      36.5         25
# ...

# %%
data2.loc[1]
# Out:
# 표측1            1.전체
# 2019.1          6.3
# 2019.2          6.2
# 2019.11        66.2
# 2019.12        61.3
# 2019.13        36.3
# 2019.14        23.6
# 2019.15        19.4
# 2019.16          19
# 2019.17        12.7
# 2019.18         8.7
# 2018.2          6.6
# 2018.8         20.4
# 2018.11        63.8
# 2018.12        57.9
# 2018.13        36.2
# 2018.14        14.8
# 2018.15        13.1
# 2018.16        12.4
# 2018.17         9.3
# 2018.18         7.4
# 2017       8,983.00
# 2017.1          9.3
# 2017.2         11.3
# 2017.5         12.3
# 2017.10        10.7
# 2017.11        62.2
# 2017.12        52.8
# 2017.13        36.4
# 2017.14        19.8
# 2017.15        25.4
# 2017.17        10.7
# 2016       8,827.00
# 2016.1          8.5
# 2016.2         10.1
# 2016.3          9.8
# 2016.5         12.2
# 2016.10         9.6
# 2016.11        67.3
# 2016.12        44.5
# 2016.13        43.2
# 2016.14        25.6
# 2016.15        25.4
# 2015       8,817.00
# 2015.1           10
# ...
